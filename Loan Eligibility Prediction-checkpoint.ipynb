# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             confusion_matrix, roc_curve, auc, classification_report)

# %%
data = {
    'income': [4000, 6000, 2500, 10000, 3000, 8000, 12000, 2000, 5000, 7000],
    'credit_score': [650, 720, 580, 800, 600, 750, 810, 550, 700, 730],
    'employment_years': [2, 5, 1, 10, 2, 6, 12, 1, 4, 7],
    'liabilities': [2000, 3000, 1500, 4000, 1000, 3500, 2500, 500, 2800, 3200],
    'loan_approved': [0, 1, 0, 1, 0, 1, 1, 0, 1, 1]
}

df = pd.DataFrame(data)
df.head()
# Out:
#    income  credit_score  employment_years  liabilities  loan_approved
# 0    4000           650                 2         2000              0
# 1    6000           720                 5         3000              1
# 2    2500           580                 1         1500              0
# 3   10000           800                10         4000              1
# 4    3000           600                 2         1000              0

# %%
X = df.drop("loan_approved", axis=1)
y = df["loan_approved"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.3, random_state=42
)

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42)
}

results = {}
metrics_summary = {}
roc_data = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)   # Sensitivity
    f1 = f1_score(y_test, y_pred)

    # Specificity
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0

    results[name] = acc
    metrics_summary[name] = {
        "Accuracy": acc,
        "Precision": prec,
        "Recall (Sensitivity)": rec,
        "Specificity": specificity,
        "F1 Score": f1
    }

    # ROC data
    if hasattr(model, "predict_proba"):
        y_score = model.predict_proba(X_test)[:, 1]
    else:
        y_score = model.decision_function(X_test)

    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    roc_data[name] = (fpr, tpr, roc_auc)

    print(f"=== {name} ===")
    print(classification_report(y_test, y_pred))
# Out:
# C:\Users\muvva\anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:1179: UndefinedMetricWarning: No negative samples in y_true, false positive value should be meaningless
#   warnings.warn(
# C:\Users\muvva\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\muvva\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
best_model_name = max(results, key=results.get)
best_model = models[best_model_name]

print(f"Best model: {best_model_name} with accuracy {results[best_model_name]:.2f}")

with open("best_model.pkl", "wb") as f:
    pickle.dump(best_model, f)

with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)
# Out:
# Best model: Logistic Regression with accuracy 0.67

# %%
new_applicants = np.array([
    [5500, 710, 3, 2000],
    [2500, 590, 1, 3000]
])

new_applicants_scaled = scaler.transform(new_applicants)
predictions = best_model.predict(new_applicants_scaled)
predictions
# Out:
# C:\Users\muvva\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([0, 0])

# %%
y_pred_best = best_model.predict(X_test)
cm_best = confusion_matrix(y_test, y_pred_best)

plt.figure(figsize=(5,4))
sns.heatmap(cm_best, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Rejected","Approved"], yticklabels=["Rejected","Approved"])
plt.title(f"Confusion Matrix - {best_model_name}")
plt.ylabel("Actual")
plt.xlabel("Predicted")
plt.show()

# %%
metrics_df = pd.DataFrame(metrics_summary).T
metrics_df.plot(kind="bar", figsize=(10,6))
plt.title("Model Performance Metrics")
plt.xticks(rotation=45)
plt.ylabel("Score")
plt.legend(loc="lower right")
plt.show()

# %%
plt.figure(figsize=(7,6))
for name, (fpr, tpr, roc_auc) in roc_data.items():
    plt.plot(fpr, tpr, label=f"{name} (AUC = {roc_auc:.2f})")
plt.plot([0,1], [0,1], "k--")
plt.title("ROC Curves")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend(loc="lower right")
plt.show()

# %%
with open("best_model.pkl", "rb") as f:
    loaded_model = pickle.load(f)
with open("scaler.pkl", "rb") as f:
    loaded_scaler = pickle.load(f)

loaded_model.predict(loaded_scaler.transform(new_applicants))
# Out:
# C:\Users\muvva\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([0, 0])

# %%
import ipywidgets as widgets
from IPython.display import display

income = widgets.IntSlider(min=1000, max=15000, step=500, description='Income:')
credit = widgets.IntSlider(min=300, max=850, step=10, description='Credit:')
years = widgets.IntSlider(min=0, max=20, description='Employment Years:')
liab = widgets.IntSlider(min=0, max=10000, step=500, description='Liabilities:')

def predict_applicant(income, credit, years, liab):
    applicant = np.array([[income, credit, years, liab]])
    applicant_scaled = scaler.transform(applicant)
    pred = best_model.predict(applicant_scaled)[0]
    print("✅ Loan Approved" if pred == 1 else "❌ Loan Rejected")

ui = widgets.VBox([income, credit, years, liab])
out = widgets.interactive_output(predict_applicant, {'income': income, 'credit': credit, 'years': years, 'liab': liab})

display(ui, out)
# Out:
# ...
# Output()
